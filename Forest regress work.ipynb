# %%
# Initial imports
import pandas as pd
from path import Path
from sklearn import tree
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
pd.options.display.max_columns = 999

# %%
# Loading data
file_path = Path("data.csv")
df_retail = pd.read_csv(file_path)
df_retail.head()
# Out:
#    Unnamed: 0             IID  AGE_  INCOME ETHNIC_CODE_GROUP  \
# 0           0  010TUGIXZ95K5R    57       8                 K
# 1           1  0109BPMLXNREXT    50       7                 J
# 2           2  0102I4L0PINZB3    54      11                 E
# 3           3  010QS307CAT5WJ    48      11                 K
# 4           4  0101EN5Q3W4AE8    32       9                 K
#
#                      AN_BIRTHDAY  POSTAL_CD LOYALTY_YN  \
# 0  1970-01-01 00:00:00.000000000      85260          Y
# 1  1970-01-01 00:00:00.000000306      20017          Y
# 2  1970-01-01 00:00:00.000001129      23233          Y
# 3  1970-01-01 00:00:00.000000204      23453          Y
# 4  1970-01-01 00:00:00.000000000      94108          Y
#
#               FIRST_ANTHRO_ORDER  LIFETIME_APPAREL_DEMAND  \
# 0  2015-03-24 00:00:00.000000000                  5059.97
# 1  2015-10-15 00:00:00.000000000                 17353.28
# 2  2017-07-11 00:00:00.000000000                  4481.17
# 3  2018-06-28 00:00:00.000000000                  8312.67
# 4  2019-07-12 00:00:00.000000000                  6528.04
#
#    LIFETIME_APPAREL_ORDERS                       ORDER_DT    ORDER_ID  \
# 0                       67  2020-06-12 00:00:00.000000000  4230042557
# 1                       54  2021-02-09 00:00:00.000000000  AP11740106
# 2                       30  2022-12-26 00:00:00.000000000  4440016787
# 3                       47  2020-09-14 00:00:00.000000000  AP08740761
# 4                       37  2022-03-31 00:00:00.000000000  AN09227509
#
#    ORDER_LINE_SEQ PURCHASE_CHANNEL_DERIVED  STORE_NUM  \
# 0               2                   RETAIL        423
# 1               3                   DIRECT       2499
# 2               1                   RETAIL        444
# 3               1                   DIRECT       2499
# 4               1                   DIRECT       2499
#
#                         STORE_NAME   STORE_ZIP                  DIVISION_NAME  \
# 0  423 SCOTTSDALE,AZ-KIERLND  (NA)  85254-2176  ANTHRO. WOMEN'S DIVISION (NA)
# 1         ANT DIRECT SELLING  (NA)      DIRECT                 OFF HOURS (NA)
# 2           444 RICHMOND, VA  (NA)  23235-1955  ANTHRO. WOMEN'S DIVISION (NA)
# 3         ANT DIRECT SELLING  (NA)      DIRECT    APPAREL EXTENDED SIZES (NA)
# 4         ANT DIRECT SELLING  (NA)      DIRECT    APPAREL EXTENDED SIZES (NA)
#
#                 DEPARTMENT_NAME                CLASS_NAME  PRODUCT_ID  \
# 0  ANTHRO. WOMEN'S BOTTOMS (NA)                PANTS (NA)    54766134
# 1       ANTHRO - OFF HOURS (NA)               LOUNGE (NA)    59001933
# 2                  JACKETS (NA)  OUTERWEAR - ANTHRO. (NA)    69997476
# 3                  PETITES (NA)      JEANS - PETITES (NA)    58280181
# 4                  PETITES (NA)    DRESSES - PETITES (NA)    66952177
#
#                    ITEM_NAME   MD_STATE  DEMAND_QTY  DEMAND_AMT states Region
# 0  ASYMMETRICAL PULL ON PANT  REG PRICE           1       52.46     AZ   West
# 1           COZY KNIT JOGGER  REG PRICE           1       44.96     DC  South
# 2  UNREAL FUR KATHMANDU COAT  REG PRICE           1      179.97     VA  South
# 3  OB HR FEMME DARTED SKINNY   MARKDOWN           1      128.00     VA  South
# 4  OB 1 SHLDR CHERRY PRNTD M   MARKDOWN           1      160.00     CA   West

# %%
df_retail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 224647 entries, 0 to 224646
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Unnamed: 0                224647 non-null  int64
#  1   IID                       224647 non-null  object
#  2   AGE_                      224647 non-null  int64
#  3   INCOME                    224647 non-null  int64
#  4   ETHNIC_CODE_GROUP         224647 non-null  object
#  5   AN_BIRTHDAY               224647 non-null  object
#  6   POSTAL_CD                 224647 non-null  int64
#  7   LOYALTY_YN                224647 non-null  object
#  8   FIRST_ANTHRO_ORDER        224647 non-null  object
#  9   LIFETIME_APPAREL_DEMAND   224647 non-null  float64
#  10  LIFETIME_APPAREL_ORDERS   224647 non-null  int64
#  11  ORDER_DT                  224647 non-null  object
#  12  ORDER_ID                  224647 non-null  object
#  13  ORDER_LINE_SEQ            224647 non-null  int64
#  14  PURCHASE_CHANNEL_DERIVED  224647 non-null  object
#  15  STORE_NUM                 224647 non-null  int64
#  16  STORE_NAME                224647 non-null  object
#  17  STORE_ZIP                 224647 non-null  object
#  18  DIVISION_NAME             224647 non-null  object
#  19  DEPARTMENT_NAME           224647 non-null  object
#  20  CLASS_NAME                224647 non-null  object
#  21  PRODUCT_ID                224647 non-null  int64
#  22  ITEM_NAME                 224647 non-null  object
#  23  MD_STATE                  224647 non-null  object
#  24  DEMAND_QTY                224647 non-null  int64
#  25  DEMAND_AMT                224647 non-null  float64
#  26  states                    224647 non-null  object
#  27  Region                    224647 non-null  object
# dtypes: float64(2), int64(9), object(17)
# memory usage: 48.0+ MB

# %%
df_retail.IID.value_counts()
# Out:
# 010NNJ93E7VKUN    8804
# 0103IPXSGJD0X6    1790
# 010EAXG020328O    1560
# 010TPQOHLPTWWR    1227
# 010EF2O2JTXADL    1076
#                   ...
# 01116AOTM3RH0M       1
# 0103TNMJG77ZAX       1
# 0113SXEV26I9ZS       1
# 010SLUETY6906O       1
# 010ITVO01DFAGM       1
# Name: IID, Length: 9008, dtype: int64

# %%
df_retail[df_retail["IID"]=="010EF2O2JTXADL"]
# Out:
#         Unnamed: 0             IID  AGE_  INCOME ETHNIC_CODE_GROUP  \
# 9                9  010EF2O2JTXADL    44       4                 K
# 10              10  010EF2O2JTXADL    44       4                 K
# 32              38  010EF2O2JTXADL    44       4                 K
# 99             123  010EF2O2JTXADL    44       4                 K
# 286            352  010EF2O2JTXADL    44       4                 K
# ...            ...             ...   ...     ...               ...
# 224117      283472  010EF2O2JTXADL    44       4                 K
# 224190      283567  010EF2O2JTXADL    44       4                 K
# 224191      283568  010EF2O2JTXADL    44       4                 K
# 224199      283577  010EF2O2JTXADL    44       4                 K
# 224545      284007  010EF2O2JTXADL    44       4                 K
#
#                           AN_BIRTHDAY  POSTAL_CD LOYALTY_YN  \
# 9       1970-01-01 00:00:00.000000505      54720          Y
# 10      1970-01-01 00:00:00.000000505      54720          Y
# 32      1970-01-01 00:00:00.000000505      54720          Y
# 99      1970-01-01 00:00:00.000000505      54720          Y
# 286     1970-01-01 00:00:00.000000505      54720          Y
# ...                               ...        ...        ...
# 224117  1970-01-01 00:00:00.000000505      54720          Y
# 224190  1970-01-01 00:00:00.000000505      54720          Y
# 224191  1970-01-01 00:00:00.000000505      54720          Y
# 224199  1970-01-01 00:00:00.000000505      54720          Y
# 224545  1970-01-01 00:00:00.000000505      54720          Y
#
#                    FIRST_ANTHRO_ORDER  LIFETIME_APPAREL_DEMAND  \
# 9       2015-02-25 00:00:00.000000000                207190.78
# 10      2015-02-25 00:00:00.000000000                207190.78
# 32      2015-02-25 00:00:00.000000000                207190.78
# 99      2015-02-25 00:00:00.000000000                207190.78
# 286     2015-02-25 00:00:00.000000000                207190.78
# ...                               ...                      ...
# 224117  2015-02-25 00:00:00.000000000                207190.78
# 224190  2015-02-25 00:00:00.000000000                207190.78
# 224191  2015-02-25 00:00:00.000000000                207190.78
# 224199  2015-02-25 00:00:00.000000000                207190.78
# 224545  2015-02-25 00:00:00.000000000                207190.78
#
#         LIFETIME_APPAREL_ORDERS                       ORDER_DT    ORDER_ID  \
# 9                           255  2022-08-09 00:00:00.000000000  AN10197715
# 10                          255  2022-08-09 00:00:00.000000000  AN10197715
# 32                          255  2022-11-25 00:00:00.000000000  AN11053273
# 99                          255  2022-01-09 00:00:00.000000000  AN08696114
# 286                         255  2022-04-25 00:00:00.000000000  AN09421365
# ...                         ...                            ...         ...
# 224117                      255  2021-07-11 00:00:00.000000000  AN07069544
# 224190                      255  2022-01-14 00:00:00.000000000  AN08736440
# 224191                      255  2022-01-14 00:00:00.000000000  AN08736440
# 224199                      255  2020-05-23 00:00:00.000000000  AN03690591
# 224545                      255  2022-01-16 00:00:00.000000000  AN08755398
#
#         ORDER_LINE_SEQ PURCHASE_CHANNEL_DERIVED  STORE_NUM  \
# 9                    1                   DIRECT       2499
# 10                   3                   DIRECT       2499
# 32                   1                   DIRECT       2499
# 99                   2                   DIRECT       2499
# 286                  4                   DIRECT       2499
# ...                ...                      ...        ...
# 224117               2                   DIRECT       2499
# 224190              19                   DIRECT       2499
# 224191              16                   DIRECT       2499
# 224199               2                   DIRECT       2499
# 224545               2                   DIRECT       2499
#
#                       STORE_NAME STORE_ZIP                  DIVISION_NAME  \
# 9       ANT DIRECT SELLING  (NA)    DIRECT  ANTHRO. WOMEN'S DIVISION (NA)
# 10      ANT DIRECT SELLING  (NA)    DIRECT  ANTHRO. WOMEN'S DIVISION (NA)
# 32      ANT DIRECT SELLING  (NA)    DIRECT  ANTHRO. WOMEN'S DIVISION (NA)
# 99      ANT DIRECT SELLING  (NA)    DIRECT  ANTHRO. WOMEN'S DIVISION (NA)
# 286     ANT DIRECT SELLING  (NA)    DIRECT  ANTHRO. WOMEN'S DIVISION (NA)
# ...                          ...       ...                            ...
# 224117  ANT DIRECT SELLING  (NA)    DIRECT  ANTHRO. WOMEN'S DIVISION (NA)
# 224190  ANT DIRECT SELLING  (NA)    DIRECT                 OFF HOURS (NA)
# 224191  ANT DIRECT SELLING  (NA)    DIRECT                 OFF HOURS (NA)
# 224199  ANT DIRECT SELLING  (NA)    DIRECT  ANTHRO. WOMEN'S DIVISION (NA)
# 224545  ANT DIRECT SELLING  (NA)    DIRECT  ANTHRO. WOMEN'S DIVISION (NA)
#
#                      DEPARTMENT_NAME               CLASS_NAME  PRODUCT_ID  \
# 9       ANTHRO. WOMEN'S DRESSES (NA)   DRESSES - ANTHRO. (NA)    68433762
# 10      ANTHRO. WOMEN'S DRESSES (NA)   DRESSES - ANTHRO. (NA)    69773133
# 32         ANTHRO. WOMEN'S TOPS (NA)  SWEATERS - ANTHRO. (NA)    69916096
# 99      ANTHRO. WOMEN'S DRESSES (NA)   DRESSES - ANTHRO. (NA)    64665839
# 286        ANTHRO. WOMEN'S TOPS (NA)   BLOUSES - ANTHRO. (NA)    67938100
# ...                              ...                      ...         ...
# 224117     ANTHRO. WOMEN'S TOPS (NA)   BLOUSES - ANTHRO. (NA)    62422860
# 224190       ANTHRO - OFF HOURS (NA)                SWIM (NA)    66701285
# 224191       ANTHRO - OFF HOURS (NA)                SWIM (NA)    64245566
# 224199     ANTHRO. WOMEN'S TOPS (NA)   BLOUSES - ANTHRO. (NA)    56103542
# 224545  ANTHRO. WOMEN'S DRESSES (NA)   DRESSES - ANTHRO. (NA)    65398703
#
#                         ITEM_NAME   MD_STATE  DEMAND_QTY  DEMAND_AMT states  \
# 9       BLACK HALO SLIM ONE SHOUL   MARKDOWN           1      375.00     WI
# 10          OB OS TXTRD RFFL MINI   MARKDOWN           1      170.00     WI
# 32      ANTIK BATIK STRIPED TURTL  REG PRICE           1       99.97     WI
# 99      FAITHFULL SV DEEP V SOLID   MARKDOWN           1      199.00     WI
# 286     OB LL PILCRO ROMY RELAXED   MARKDOWN           1       98.00     WI
# ...                           ...        ...         ...         ...    ...
# 224117    CMS SLVLS PRINTED SHELL  REG PRICE           1       44.96     WI
# 224190  SOLID AND STRIPED KAIA RU   MARKDOWN           1       88.00     WI
# 224191  ROS GARDEN SHORT SOFIA DR   MARKDOWN           1      235.00     WI
# 224199    OB THE CLASSIC DYE TECH  REG PRICE           1       73.50     WI
# 224545  OB SV SOLID TAFFATA ALINE  REG PRICE           1       59.97     WI
#
#          Region
# 9       Midwest
# 10      Midwest
# 32      Midwest
# 99      Midwest
# 286     Midwest
# ...         ...
# 224117  Midwest
# 224190  Midwest
# 224191  Midwest
# 224199  Midwest
# 224545  Midwest
#
# [1076 rows x 28 columns]

# %%
df_retail.columns
# Out:
# Index(['Unnamed: 0', 'IID', 'AGE_', 'INCOME', 'ETHNIC_CODE_GROUP',
#        'AN_BIRTHDAY', 'POSTAL_CD', 'LOYALTY_YN', 'FIRST_ANTHRO_ORDER',
#        'LIFETIME_APPAREL_DEMAND', 'LIFETIME_APPAREL_ORDERS', 'ORDER_DT',
#        'ORDER_ID', 'ORDER_LINE_SEQ', 'PURCHASE_CHANNEL_DERIVED', 'STORE_NUM',
#        'STORE_NAME', 'STORE_ZIP', 'DIVISION_NAME', 'DEPARTMENT_NAME',
#        'CLASS_NAME', 'PRODUCT_ID', 'ITEM_NAME', 'MD_STATE', 'DEMAND_QTY',
#        'DEMAND_AMT', 'states', 'Region'],
#       dtype='object')

# %%
# #predictors=['AGE_', 'INCOME', 'ETHNIC_CODE_GROUP',
#         'POSTAL_CD', 'LOYALTY_YN', 'LIFETIME_APPAREL_DEMAND', 'LIFETIME_APPAREL_ORDERS',
#         'PURCHASE_CHANNEL_DERIVED', 'STORE_NUM',
#         'DIVISION_NAME', 'DEPARTMENT_NAME',
#        'CLASS_NAME', 'PRODUCT_ID', 'ITEM_NAME', 'MD_STATE', 'DEMAND_QTY',
#        'DEMAND_AMT', 'states', 'Region']

# %%
df_retail2=df_retail[['IID', 'ORDER_DT','DEMAND_AMT']].copy()
df_retail2.head()
# Out:
#               IID                       ORDER_DT  DEMAND_AMT
# 0  010TUGIXZ95K5R  2020-06-12 00:00:00.000000000       52.46
# 1  0109BPMLXNREXT  2021-02-09 00:00:00.000000000       44.96
# 2  0102I4L0PINZB3  2022-12-26 00:00:00.000000000      179.97
# 3  010QS307CAT5WJ  2020-09-14 00:00:00.000000000      128.00
# 4  0101EN5Q3W4AE8  2022-03-31 00:00:00.000000000      160.00

# %%
df_retail2['ORDER_DT']=pd.to_datetime(df_retail2['ORDER_DT'])

# %%
df_retail2.dtypes
# Out:
# IID                   object
# ORDER_DT      datetime64[ns]
# DEMAND_AMT           float64
# dtype: object

# %%
df_retail2.head()
# Out:
#               IID   ORDER_DT  DEMAND_AMT
# 0  010TUGIXZ95K5R 2020-06-12       52.46
# 1  0109BPMLXNREXT 2021-02-09       44.96
# 2  0102I4L0PINZB3 2022-12-26      179.97
# 3  010QS307CAT5WJ 2020-09-14      128.00
# 4  0101EN5Q3W4AE8 2022-03-31      160.00

# %%
df_retail2.shape
# Out:
# (224647, 3)

# %%
df_retail2_agg=df_retail2.groupby(['IID', 'ORDER_DT']).sum()[['DEMAND_AMT']].reset_index()
df_retail2_agg.shape
# Out:
# (92268, 3)
